# %%
import pandas as pd

# %%
df_dataset_systagram1_5_0_violation_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-violation-matrix-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_unit_compartment_mapping_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-unit-compartment-mapping-matrix-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_conformance_of_rules_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-conformance-of-rules-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_degradation_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-degradation-matrix-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_degree_of_conformance_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-degree-of-conformance-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_compartment_description_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-compartment-description-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_metric_suite_description_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-metric-suite-description-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_basic_statistics_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-basic-statistics-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_rule_violation_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-rule-violation-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_0_metrics_suite_ = pd.read_csv('../arcatchreports/systagram1.5.0/systagram1.5.0-metrics-suite-2020-04-14-21-15-44.csv', sep=';')
df_dataset_systagram1_5_1_rule_violation_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-rule-violation-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_metric_suite_description_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-metric-suite-description-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_basic_statistics_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-basic-statistics-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_compartment_description_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-compartment-description-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_degree_of_conformance_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-degree-of-conformance-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_unit_compartment_mapping_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-unit-compartment-mapping-matrix-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_violation_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-violation-matrix-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_metrics_suite_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-metrics-suite-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_conformance_of_rules_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-conformance-of-rules-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_5_1_degradation_matrix_ = pd.read_csv('../arcatchreports/systagram1.5.1/systagram1.5.1-degradation-matrix-2020-04-14-21-15-46.csv', sep=';')
df_dataset_systagram1_4_0_unit_compartment_mapping_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-unit-compartment-mapping-matrix-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_rule_violation_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-rule-violation-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_violation_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-violation-matrix-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_metric_suite_description_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-metric-suite-description-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_degradation_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-degradation-matrix-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_compartment_description_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-compartment-description-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_basic_statistics_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-basic-statistics-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_degree_of_conformance_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-degree-of-conformance-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_conformance_of_rules_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-conformance-of-rules-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_0_metrics_suite_ = pd.read_csv('../arcatchreports/systagram1.4.0/systagram1.4.0-metrics-suite-2020-04-14-21-15-40.csv', sep=';')
df_dataset_systagram1_4_1_conformance_of_rules_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-conformance-of-rules-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_basic_statistics_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-basic-statistics-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_degradation_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-degradation-matrix-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_degree_of_conformance_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-degree-of-conformance-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_unit_compartment_mapping_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-unit-compartment-mapping-matrix-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_compartment_description_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-compartment-description-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_rule_violation_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-rule-violation-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_violation_matrix_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-violation-matrix-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_metrics_suite_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-metrics-suite-2020-04-14-21-15-42.csv', sep=';')
df_dataset_systagram1_4_1_metric_suite_description_ = pd.read_csv('../arcatchreports/systagram1.4.1/systagram1.4.1-metric-suite-description-2020-04-14-21-15-42.csv', sep=';')

# %%
df_dataset_systagram1_4_0_unit_compartment_mapping_matrix_
# Out:
#                                                  Unit  CPT01  Unnamed: 2
# 0                     br.ufc.great.sysadmin.MvcConfig    NaN         NaN
# 1             br.ufc.great.sysadmin.SystemApplication    NaN         NaN
# 2   br.ufc.great.sysadmin.controller.AccessControl...    NaN         NaN
# 3   br.ufc.great.sysadmin.controller.DashboardCont...    NaN         NaN
# 4   br.ufc.great.sysadmin.controller.FileUploadCon...    NaN         NaN
# 5   br.ufc.great.sysadmin.controller.MyErrorContro...    NaN         NaN
# 6   br.ufc.great.sysadmin.controller.PersonController    NaN         NaN
# 7     br.ufc.great.sysadmin.controller.UserController    NaN         NaN
# 8           br.ufc.great.sysadmin.model.AbstractModel    NaN         NaN
# 9                 br.ufc.great.sysadmin.model.Comment    NaN         NaN
# 10                  br.ufc.great.sysadmin.model.Likes    NaN         NaN
# 11                 br.ufc.great.sysadmin.model.Person    NaN         NaN
# ...

# %%
df_dataset_systagram1_4_0_rule_violation_
# Out:
# Empty DataFrame
# Columns: [Rule Id, Violation Kind, Violating Unit, Violation Label, First Unit, Second Unit]
# Index: []

# %%
df_dataset_systagram1_4_0_violation_matrix_
# Out:
#          Unit  Ocurrences  Class DeF
# 0  Ocurrences         NaN        NaN
# 1    Rule DeF         NaN        NaN

# %%
df_dataset_systagram1_4_0_metric_suite_description_
# Out:
#    Short Name                               Full Name
# 0         WMC              Weighted Methods per Class
# 1         DIT               Depth of Inheritance Tree
# 2         NOC                      Number of Children
# 3         CBO                Coupling Between Objects
# 4         RFC                      Response For Class
# 5        LCOM          Lack of Cohesion of Methods v1
# 6       LCOM2          Lack of Cohesion of Methods v2
# 7       LCOM3          Lack of Cohesion of Methods v3
# 8         CCC             Class Cyclomatic Complexity
# 9         LoC                           Lines of Code
# 10        NoI                   Number of Invovations
# 11        NoM                       Number of Methods
# 12       NoPM                Number of Public Methods
# 13        NoA           Number of Declared Attributes
# 14       NoPA             Number of Public Attributes
# 15         Ca                       Afferent Coupling
# ...

# %%
df_dataset_systagram1_4_0_degradation_matrix_
# Out:
#          Unit  Ocurrences  Class DeF
# 0  Ocurrences         NaN        NaN
# 1    Rule DeF         NaN        NaN

# %%
df_dataset_systagram1_4_0_compartment_description_
# Out:
#       Id      Label               Class Search Pattern Method Search Pattern
# 0  CPT01  systagram  br.ufc.great.sysadmin.systagram.*                   *:*

# %%
df_dataset_systagram1_4_0_basic_statistics_
# Out:
#                             Project Name                         Systagram
# 0                    Project Source Path  ./systagram/v1-4-0/src/main/java
# 1                        Number of Units                                39
# 2                   Number of Exceptions                                 0
# 3                          Lines of Code                            2930.0
# 4              Catch Block Lines of Code                              13.0
# 5                Overall Number of Rules                                16
# 6        Overall Number of Passing Rules                                16
# 7             Number of Anti-Drift Rules                                16
# 8     Number of Anit-Drift Passing Rules                                16
# 9           Number of Anti-Erosion Rules                                 0
# 10  Number of Anti-Erosion Passing Rules                                 0

# %%
df_dataset_systagram1_4_1_basic_statistics_
# Out:
#                             Project Name                         Systagram
# 0                    Project Source Path  ./systagram/v1-4-1/src/main/java
# 1                        Number of Units                                39
# 2                   Number of Exceptions                                 0
# 3                          Lines of Code                            3040.0
# 4              Catch Block Lines of Code                              13.0
# 5                Overall Number of Rules                                16
# 6        Overall Number of Passing Rules                                16
# 7             Number of Anti-Drift Rules                                16
# 8     Number of Anit-Drift Passing Rules                                16
# 9           Number of Anti-Erosion Rules                                 0
# 10  Number of Anti-Erosion Passing Rules                                 0

# %%
df_dataset_systagram1_5_0_basic_statistics_
# Out:
#                             Project Name                         Systagram
# 0                    Project Source Path  ./systagram/v1-5-0/src/main/java
# 1                        Number of Units                                41
# 2                   Number of Exceptions                                 0
# 3                          Lines of Code                            3310.0
# 4              Catch Block Lines of Code                              21.0
# 5                Overall Number of Rules                                16
# 6        Overall Number of Passing Rules                                16
# 7             Number of Anti-Drift Rules                                16
# 8     Number of Anit-Drift Passing Rules                                16
# 9           Number of Anti-Erosion Rules                                 0
# 10  Number of Anti-Erosion Passing Rules                                 0

# %%
df_dataset_systagram1_5_1_basic_statistics_
# Out:
#                             Project Name                         Systagram
# 0                    Project Source Path  ./systagram/v1-5-1/src/main/java
# 1                        Number of Units                                38
# 2                   Number of Exceptions                                 0
# 3                          Lines of Code                            2859.0
# 4              Catch Block Lines of Code                               4.0
# 5                Overall Number of Rules                                16
# 6        Overall Number of Passing Rules                                16
# 7             Number of Anti-Drift Rules                                16
# 8     Number of Anit-Drift Passing Rules                                16
# 9           Number of Anti-Erosion Rules                                 0
# 10  Number of Anti-Erosion Passing Rules                                 0

# %%
print('1.4.0', df_dataset_systagram1_4_0_degree_of_conformance_)
print('1.4.1', df_dataset_systagram1_4_1_degree_of_conformance_)
print('1.5.0', df_dataset_systagram1_5_0_degree_of_conformance_)
print('1.5.1', df_dataset_systagram1_5_1_degree_of_conformance_)
# Out:
# 1.4.0    Overall  Erosion  Drift
# 0      1.0      1.0    1.0
# 1.4.1    Overall  Erosion  Drift
# 0      1.0      1.0    1.0
# 1.5.0    Overall  Erosion  Drift
# 0      1.0      1.0    1.0
# 1.5.1    Overall  Erosion  Drift
# 0      1.0      1.0    1.0

# %%
df_dataset_systagram1_4_0_conformance_of_rules_
# Out:
#    Rule Id  Rule Label Criticality Label  Criticality Value  \
# 0    ADR06         NaN           WARNING                  1
# 1    ADR02         NaN           WARNING                  1
# 2    ADR07         NaN           WARNING                  1
# 3    ADR11         NaN           WARNING                  1
# 4    ADR13         NaN           WARNING                  1
# 5    ADR03         NaN           WARNING                  1
# 6    ADR05         NaN           WARNING                  1
# 7    ADR15         NaN           WARNING                  1
# 8    ADR14         NaN           WARNING                  1
# 9    ADR09         NaN           WARNING                  1
# 10   ADR04         NaN           WARNING                  1
# 11   ADR08         NaN           WARNING                  1
# 12   ADR01         NaN           WARNING                  1
# 13   ADR10         NaN           WARNING                  1
# 14   ADR16         NaN           WARNING                  1
# ...

# %%
df_dataset_systagram1_4_1_conformance_of_rules_
# Out:
#    Rule Id  Rule Label Criticality Label  Criticality Value  \
# 0    ADR10         NaN           WARNING                  1
# 1    ADR04         NaN           WARNING                  1
# 2    ADR05         NaN           WARNING                  1
# 3    ADR06         NaN           WARNING                  1
# 4    ADR07         NaN           WARNING                  1
# 5    ADR02         NaN           WARNING                  1
# 6    ADR09         NaN           WARNING                  1
# 7    ADR11         NaN           WARNING                  1
# 8    ADR12         NaN           WARNING                  1
# 9    ADR13         NaN           WARNING                  1
# 10   ADR03         NaN           WARNING                  1
# 11   ADR08         NaN           WARNING                  1
# 12   ADR16         NaN           WARNING                  1
# 13   ADR15         NaN           WARNING                  1
# 14   ADR01         NaN           WARNING                  1
# ...

# %%
df_dataset_systagram1_5_0_conformance_of_rules_
# Out:
#    Rule Id  Rule Label Criticality Label  Criticality Value  \
# 0    ADR14         NaN           WARNING                  1
# 1    ADR08         NaN           WARNING                  1
# 2    ADR04         NaN           WARNING                  1
# 3    ADR02         NaN           WARNING                  1
# 4    ADR07         NaN           WARNING                  1
# 5    ADR06         NaN           WARNING                  1
# 6    ADR12         NaN           WARNING                  1
# 7    ADR15         NaN           WARNING                  1
# 8    ADR10         NaN           WARNING                  1
# 9    ADR05         NaN           WARNING                  1
# 10   ADR09         NaN           WARNING                  1
# 11   ADR13         NaN           WARNING                  1
# 12   ADR01         NaN           WARNING                  1
# 13   ADR11         NaN           WARNING                  1
# 14   ADR16         NaN           WARNING                  1
# ...

# %%
df_dataset_systagram1_5_1_conformance_of_rules_
# Out:
#    Rule Id  Rule Label Criticality Label  Criticality Value  \
# 0    ADR13         NaN           WARNING                  1
# 1    ADR07         NaN           WARNING                  1
# 2    ADR16         NaN           WARNING                  1
# 3    ADR15         NaN           WARNING                  1
# 4    ADR11         NaN           WARNING                  1
# 5    ADR04         NaN           WARNING                  1
# 6    ADR05         NaN           WARNING                  1
# 7    ADR12         NaN           WARNING                  1
# 8    ADR08         NaN           WARNING                  1
# 9    ADR10         NaN           WARNING                  1
# 10   ADR02         NaN           WARNING                  1
# 11   ADR06         NaN           WARNING                  1
# 12   ADR03         NaN           WARNING                  1
# 13   ADR09         NaN           WARNING                  1
# 14   ADR01         NaN           WARNING                  1
# ...

# %%
my_metrics_columns = ['Unit','CBO','CCC','Ca', 'Ce', 'RFC', 'LoC']

# %%
df_dataset_systagram1_4_0_metrics_suite_[my_metrics_columns].sort_values('CBO', ascending=False)
# Out:
#                                                  Unit   CBO   CCC    Ca    Ce  \
# 5   br.ufc.great.sysadmin.controller.FileUploadCon...  46.0  42.0   1.0  45.0
# 17  br.ufc.great.sysadmin.util.aws.s3.S3ClientMani...  44.0  28.0   3.0  43.0
# 25    br.ufc.great.sysadmin.controller.UserController  40.0  53.0   1.0  35.0
# 3   br.ufc.great.sysadmin.controller.PersonController  38.0  49.0   1.0  34.0
# 14           br.ufc.great.sysadmin.util.GeradorQRCode  29.0   4.0   1.0  29.0
# 10  br.ufc.great.sysadmin.controller.DashboardCont...  29.0  19.0   1.0  28.0
# 18                 br.ufc.great.sysadmin.model.Person  27.0  50.0  22.0  22.0
# 15  br.ufc.great.sysadmin.controller.AccessControl...  25.0  22.0   1.0  23.0
# 23                  br.ufc.great.sysadmin.model.Users  24.0  26.0  13.0  23.0
# 2                    br.ufc.great.sysadmin.model.Post  21.0  33.0   8.0  18.0
# 7   br.ufc.great.sysadmin.controller.MyErrorContro...  20.0  12.0   1.0  20.0
# ...

# %%
df_dataset_systagram1_4_1_metrics_suite_[my_metrics_columns].sort_values('CBO', ascending=False)
# Out:
#                                                  Unit   CBO   CCC    Ca    Ce  \
# 5   br.ufc.great.sysadmin.controller.FileUploadCon...  46.0  42.0   1.0  45.0
# 17  br.ufc.great.sysadmin.util.aws.s3.S3ClientMani...  44.0  28.0   3.0  43.0
# 25    br.ufc.great.sysadmin.controller.UserController  40.0  59.0   1.0  35.0
# 3   br.ufc.great.sysadmin.controller.PersonController  40.0  55.0   1.0  34.0
# 10  br.ufc.great.sysadmin.controller.DashboardCont...  31.0  19.0   1.0  28.0
# 14           br.ufc.great.sysadmin.util.GeradorQRCode  29.0   4.0   1.0  29.0
# 18                 br.ufc.great.sysadmin.model.Person  29.0  54.0  22.0  22.0
# 15  br.ufc.great.sysadmin.controller.AccessControl...  25.0  22.0   1.0  23.0
# 23                  br.ufc.great.sysadmin.model.Users  24.0  26.0  13.0  23.0
# 2                    br.ufc.great.sysadmin.model.Post  21.0  33.0   8.0  18.0
# 7   br.ufc.great.sysadmin.controller.MyErrorContro...  20.0  12.0   1.0  20.0
# ...

# %%
df_dataset_systagram1_5_0_metrics_suite_[my_metrics_columns].sort_values('CBO', ascending=False)
# Out:
#                                                  Unit   CBO   CCC    Ca    Ce  \
# 6   br.ufc.great.sysadmin.controller.FileUploadCon...  46.0  42.0   1.0  45.0
# 18  br.ufc.great.sysadmin.util.aws.s3.S3ClientMani...  44.0  28.0   3.0  43.0
# 3   br.ufc.great.sysadmin.controller.PersonController  42.0  55.0   1.0  34.0
# 27    br.ufc.great.sysadmin.controller.UserController  40.0  59.0   1.0  35.0
# 23  br.ufc.great.sysadmin.util.dynamodb.DynamoDBMa...  34.0  18.0   0.0   0.0
# 11  br.ufc.great.sysadmin.controller.DashboardCont...  31.0  19.0   1.0  28.0
# 19                 br.ufc.great.sysadmin.model.Person  29.0  54.0  22.0  22.0
# 15           br.ufc.great.sysadmin.util.GeradorQRCode  29.0   4.0   1.0  29.0
# 16  br.ufc.great.sysadmin.controller.AccessControl...  25.0  22.0   1.0  23.0
# 25                  br.ufc.great.sysadmin.model.Users  24.0  26.0  13.0  23.0
# 2                    br.ufc.great.sysadmin.model.Post  21.0  33.0   8.0  18.0
# ...

# %%
df_dataset_systagram1_5_1_metrics_suite_[my_metrics_columns].sort_values('CBO', ascending=False)
# Out:
#                                                  Unit   CBO   CCC    Ca    Ce  \
# 5   br.ufc.great.sysadmin.controller.FileUploadCon...  44.0  44.0   1.0  45.0
# 26    br.ufc.great.sysadmin.controller.UserController  42.0  64.0   1.0  35.0
# 2   br.ufc.great.sysadmin.controller.PersonController  39.0  55.0   1.0  34.0
# 29          br.ufc.great.sysadmin.domain.model.Person  29.0  54.0   0.0   0.0
# 16           br.ufc.great.sysadmin.util.GeradorQRCode  29.0   4.0   1.0  29.0
# 17  br.ufc.great.sysadmin.controller.AccessControl...  27.0  20.0   1.0  23.0
# 25           br.ufc.great.sysadmin.domain.model.Users  27.0  26.0   0.0   0.0
# 12  br.ufc.great.sysadmin.controller.DashboardCont...  24.0  17.0   1.0  28.0
# 24            br.ufc.great.sysadmin.domain.model.Post  21.0  33.0   0.0   0.0
# 8   br.ufc.great.sysadmin.controller.MyErrorContro...  20.0  12.0   1.0  20.0
# 27           br.ufc.great.sysadmin.util.MySessionInfo  20.0  26.0   7.0  20.0
# ...
